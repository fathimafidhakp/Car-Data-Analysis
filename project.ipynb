# %% [markdown]
# # CAR DETAILS ANALYSIS

# %% [markdown]
# ##### THIS IS MY FIRST PROJECT

# %% [markdown]
# ## AIM :
#
# This project analyzes car data to understand price,mileage,fuel type,and other features

# %% [markdown]
#  ## PROBLEM STATEMENT :-

# %% [markdown]
# The objective of this project is to analyze a dataset of used cars to understand the key factors that influence the selling price.The dataset includes features such as year ,fuel type,transmission,ownership,mileage,engine capacity,and maximum power
#
# the goal is to build a model that can accuratly predict the selling price of car based on these features ,while also identifying the most important variables  affecting price.This will help in making better pricing decisions for buyers and sellers in the used car market

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("car.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# ### Inspect Data

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# -  Displays The First Five Rows Of Data frame

# %%
df.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %% [markdown]
# - Displays the last 5 rows of the frame

# %%
df.sample()
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 2058  Maruti Alto 800 LXI  2016         245000      50000  Petrol  Individual
#
#      transmission        owner     mileage  engine max_power         torque  \
# 2058       Manual  First Owner  22.74 kmpl  796 CC  47.3 bhp  69Nm@ 3500rpm
#
#       seats
# 2058    5.0

# %%
df.dtypes
# Out:
# name                 str
# year               int64
# selling_price      int64
# km_driven          int64
# fuel                 str
# seller_type          str
# transmission         str
# owner                str
# mileage              str
# engine               str
# max_power            str
# torque               str
# seats            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='str')

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   str
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   str
#  5   seller_type    8128 non-null   str
#  6   transmission   8128 non-null   str
#  7   owner          8128 non-null   str
#  8   mileage        7907 non-null   str
#  9   engine         7907 non-null   str
#  10  max_power      7913 non-null   str
#  11  torque         7906 non-null   str
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), str(9)
# memory usage: 825.6 KB

# %% [markdown]
# - Total 13 Columns
# - Total 8128 entries
# - Memory Usage = 825.6 KB
# - Five Columns Have missing Values : milage,engine,max_power,torque,seats
# - Data Type Issue : milege,engine,max_power,Torque are 'str'but should be numeric

# %% [markdown]
# ### Seleting Columns

# %%
# single column

df['name']
# Out:
# 0             Maruti Swift Dzire VDI
# 1       Skoda Rapid 1.5 TDI Ambition
# 2           Honda City 2017-2020 EXi
# 3          Hyundai i20 Sportz Diesel
# 4             Maruti Swift VXI BSIII
#                     ...
# 8123               Hyundai i20 Magna
# 8124           Hyundai Verna CRDi SX
# 8125          Maruti Swift Dzire ZDi
# 8126                 Tata Indigo CR4
# 8127                 Tata Indigo CR4
# Name: name, Length: 8128, dtype: str

# %%
# Multiple Column

df[['name','year']]
# Out:
#                               name  year
# 0           Maruti Swift Dzire VDI  2014
# 1     Skoda Rapid 1.5 TDI Ambition  2014
# 2         Honda City 2017-2020 EXi  2006
# 3        Hyundai i20 Sportz Diesel  2010
# 4           Maruti Swift VXI BSIII  2007
# ...                            ...   ...
# 8123             Hyundai i20 Magna  2013
# 8124         Hyundai Verna CRDi SX  2007
# 8125        Maruti Swift Dzire ZDi  2009
# 8126               Tata Indigo CR4  2013
# 8127               Tata Indigo CR4  2013
#
# [8128 rows x 2 columns]

# %% [markdown]
# ## Filtering

# %%
df[df['year']>2010]
# Out:
#                                       name  year  selling_price  km_driven  \
# 0                   Maruti Swift Dzire VDI  2014         450000     145500
# 1             Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 5            Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 8                         Toyota Etios VXD  2011         350000      90000
# 9     Ford Figo Diesel Celebration Edition  2013         200000     169000
# ...                                    ...   ...            ...        ...
# 8121     Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122            Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                     Hyundai i20 Magna  2013         320000     110000
# 8126                       Tata Indigo CR4  2013         290000      25000
# 8127                       Tata Indigo CR4  2013         290000      25000
#
# ...

# %% [markdown]
# - After filtering,these are 6651 rows and 13 columns remaining

# %%
df[df['fuel']=='Petrol']
# Out:
#                                    name  year  selling_price  km_driven  \
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 11                        Maruti Zen LX  2005          92000     100000
# ...                                 ...   ...            ...        ...
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8123                  Hyundai i20 Magna  2013         320000     110000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# After filtering ,the dataset has 3631 rows and 13 columns and only petrol cars are present in the fuel column

# %%
df[df['owner']=='First Owner']
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 6      Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# ...                             ...   ...            ...        ...     ...
# 8120        Hyundai Santro Xing GLS  2008         120000     191000  Petrol
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# - After filtering 1st owner only ,the dataset has 5289 rows and 13 columns

# %%
df[df['selling_price']>2000000]
# Out:
#                                     name  year  selling_price  km_driven  \
# 41    Jeep Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 82                BMW X1 sDrive20i xLine  2016        2500000      30000
# 131           Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 132                        Lexus ES 300h  2019        5150000      20000
# 133       Jaguar XF 2.0 Diesel Portfolio  2017        3200000      45000
# ...                                  ...   ...            ...        ...
# 7873          BMW X4 M Sport X xDrive20d  2019        5500000       8500
# 7876               Volvo V40 D3 R-Design  2018        2475000       2000
# 7922          Skoda Kodiaq 2.0 TDI Style  2018        2800000      40000
# 7930       Volvo S90 D4 Inscription BSIV  2019        5500000      17000
# 7931  Ford Endeavour 2.2 Titanium AT 4X2  2016        2100000      85000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - After filtering for selling_price above 20,00,000 the dataset has 358 rows and 13 columns the row reduces because pnly 358 cars have sellingprice greater than 20 lakhs

# %%
df[(df['transmission']== 'Automatic') & (df['seller_type']=='Dealer')]
# Out:
#                                      name  year  selling_price  km_driven  \
# 44              Maruti Swift Dzire VXi AT  2018         675000      23300
# 49             Mercedes-Benz B Class B180  2014        1450000      27800
# 55    Toyota Innova Crysta 2.8 ZX AT BSIV  2016        1650000     127700
# 57             Audi A6 2.0 TDI Technology  2013        1750000      33900
# 58        Toyota Corolla Altis 1.8 VL CVT  2018        1590000      25000
# ...                                   ...   ...            ...        ...
# 8045    Renault Duster RXZ 110PS AMT BSIV  2017         750000      20171
# 8052               Honda CR-V 2.4L 4WD AT  2012         750000      50171
# 8057                 Honda Accord 2.4 A/T  2013         580000      50000
# 8058              Audi A3 40 TFSI Premium  2017        1689999       8000
# 8063       Hyundai Creta 1.6 SX Automatic  2016         890000      40000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - After filtering for automatic cars sold by dealers ,these  are 459 rows and 13 columns

# %%
# Selecting Rows

df.iloc[12] # single row
# Out:
# name             Maruti Swift Dzire VDi
# year                               2009
# selling_price                    280000
# km_driven                        140000
# fuel                             Diesel
# seller_type                  Individual
# transmission                     Manual
# owner                      Second Owner
# mileage                       19.3 kmpl
# engine                          1248 CC
# max_power                      73.9 bhp
# torque                   190Nm@ 2000rpm
# seats                               5.0
# Name: 12, dtype: object

# %%
df.iloc[3:12] # portion
# Out:
#                                     name  year  selling_price  km_driven  \
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
#
#       fuel seller_type transmission         owner     mileage   engine  \
# 3   Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4   Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
# ...

# %%
# Loc Method

df.loc[500,'mileage']
# Out:
# '17.5 kmpl'

# %%
df.loc[450,'km_driven']
# Out:
# np.int64(25000)

# %% [markdown]
# ### Rename Column

# %%
df.rename(columns={"selling_price":"price"},inplace=True)
df.head(5)
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage   engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - The column selling_price has been renamed to price in the dataset

# %% [markdown]
# ### Value Count

# %%
print("values in owner column")
df['owner'].value_counts()
# Out:
# values in owner column
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# - Most cars in the datasets are 1st owner at 5289 and the least are test drive car is 5

# %%
print("values in seller_type column  ")
df['seller_type'].value_counts()
# Out:
# values in seller_type column
# seller_type
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: count, dtype: int64

# %% [markdown]
# - Individual sellers have the higher count with 6766 cars

# %%
print("values in fuel column")
df['fuel'].value_counts()
# Out:
# values in fuel column
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %% [markdown]
# - Diesel is the most common fuel type with 4402 cars

# %%
print("values in transmission column")
df['transmission'].value_counts()
# Out:
# values in transmission column
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %% [markdown]
# - These are 7078 manual cars 1050 automatic cars ,most cars are manual

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Clean Numerical Columns With Charecters

# %%
# Remove text unit and convert to numbers 
df['engine']=pd.to_numeric(
    df['engine']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)

df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage  engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248.0      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498.0  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497.0      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396.0      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298.0    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - Text was removed from the engine columns and it was changed to numbers

# %%
df['max_power']=pd.to_numeric(
    df['max_power']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)

df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner     mileage  engine  max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248.0      74.00
# 1       Manual  Second Owner  21.14 kmpl  1498.0     103.52
# 2       Manual   Third Owner   17.7 kmpl  1497.0      78.00
# 3       Manual   First Owner   23.0 kmpl  1396.0      90.00
# 4       Manual   First Owner   16.1 kmpl  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# - Text was removed from the max_power columns and it was changed to numbers

# %%
df['mileage']=pd.to_numeric(
    df['mileage']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)

df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  \
# 0       Manual   First Owner    23.40  1248.0      74.00
# 1       Manual  Second Owner    21.14  1498.0     103.52
# 2       Manual   Third Owner    17.70  1497.0      78.00
# 3       Manual   First Owner    23.00  1396.0      90.00
# 4       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# ...

# %% [markdown]
# - Test was removed from the mileage column

# %%
# df['torque']=pd.to_numeric(
#     df['torque']
#     .astype(str)
#     .str.replace(r'[^0-9.-]','',regex=True)
#     .replace('',None),
#     errors='coerce'
# )
# This is not worked

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8128 non-null   str
#  1   year          8128 non-null   int64
#  2   price         8128 non-null   int64
#  3   km_driven     8128 non-null   int64
#  4   fuel          8128 non-null   str
#  5   seller_type   8128 non-null   str
#  6   transmission  8128 non-null   str
#  7   owner         8128 non-null   str
#  8   mileage       7907 non-null   float64
#  9   engine        7907 non-null   float64
#  10  max_power     7912 non-null   float64
#  11  torque        7906 non-null   str
#  12  seats         7907 non-null   float64
# dtypes: float64(4), int64(3), str(6)
# memory usage: 825.6 KB

# %% [markdown]
# ### Drop Column

# %%
df.drop(columns=['torque'],inplace=True)

# %%
df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00    5.0
# 1       Manual  Second Owner    21.14  1498.0     103.52    5.0
# 2       Manual   Third Owner    17.70  1497.0      78.00    5.0
# 3       Manual   First Owner    23.00  1396.0      90.00    5.0
# 4       Manual   First Owner    16.10  1298.0      88.20    5.0

# %%
df.shape
# Out:
# (8128, 12)

# %%
df.isnull().sum()
# Out:
# name              0
# year              0
# price             0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage         221
# engine          221
# max_power       216
# seats           221
# dtype: int64

# %% [markdown]
# ### Finding Missing Values

# %% [markdown]
# - Numerical - fill with median
# - Catogorical - fill wiith mode

# %%
df['mileage']=df['mileage'].fillna(df['engine'].median())

# %%
df['max_power']=df['max_power'].fillna(df['max_power'].median())

# %%
df['seats']=df['seats'].fillna(df['seats'].median())

# %%
df['engine']=df['engine'].fillna(df['engine'].median())

# %% [markdown]
# - The missing value in seats ,mileage,engine,and max_power columns were filled using the median of each column

# %%
df.isnull().sum()
# Out:
# name            0
# year            0
# price           0
# km_driven       0
# fuel            0
# seller_type     0
# transmission    0
# owner           0
# mileage         0
# engine          0
# max_power       0
# seats           0
# dtype: int64

# %% [markdown]
# - All missing values are filled no fill left

# %%
df.shape
# Out:
# (8128, 12)

# %% [markdown]
# - Dataset shape is 8128 rows and 12 columns

# %%
df['seats']=df['seats'].astype(int)
df.dtypes
# Out:
# name                str
# year              int64
# price             int64
# km_driven         int64
# fuel                str
# seller_type         str
# transmission        str
# owner               str
# mileage         float64
# engine          float64
# max_power       float64
# seats             int64
# dtype: object

# %% [markdown]
# - The seats changed to int64 all data types are now correct data cleaning is completed

# %%
df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %% [markdown]
# ### Handing Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %% [markdown]
# - There are 1202 duplicate rows present in data set

# %%
print('Before:', df.shape)
df=df.drop_duplicates()
print('After:', df.shape)
# Out:
# Before: (8128, 12)
# After: (6926, 12)

# %% [markdown]
# - 1202 duplicate rows were removed ,dataset now has 6929 unique rows and 12 columns with no duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - No dulicate row remain ,data is clean with 0  duplicates

# %%
df=df[df['mileage']!=1248.0]

# %% [markdown]
# ### Verifying Data Cleaning

# %%
df.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %%
df.shape
# Out:
# (6718, 12)

# %%
df.sample(10)
# Out:
#                                       name  year   price  km_driven    fuel  \
# 1625                       Nissan Micra XV  2011  300000      60000  Petrol
# 192      Maruti Wagon R VXI BS IV with ABS  2010  215000     120600  Petrol
# 6355              Honda City 2017-2020 GXi  2008  250000     100000  Petrol
# 6844                 Maruti Swift VDI BSIV  2015  459999     100000  Diesel
# 4685                    Maruti Wagon R VXI  2016  355000      60000  Petrol
# 193        Hyundai Verna Transform SX VTVT  2010  320000     100000  Petrol
# 1909                      Mahindra Xylo D2  2010  300000     100000  Diesel
# 7339  Maruti Celerio ZXI Optional AMT BSIV  2016  434999      10000  Petrol
# 1351   Hyundai i20 Magna 1.4 CRDi (Diesel)  2013  325000      70000  Diesel
# 6006           Renault KWID Climber 1.0 MT  2017  330000      20000  Petrol
#
#      seller_type transmission         owner  mileage  engine  max_power  seats
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='str')

# %% [markdown]
# ### Saving The Data

# %%
# Save the survivors to a  new CSV  file
df.to_csv('car_cleaned.csv',index=False)

# %% [markdown]
# - Cleaned data set save as car_cleaned .csv

# %% [markdown]
# ### Load The Cleaned Data

# %%
df_new=pd.read_csv("car_cleaned.csv")
df_new.head()
# Out:
#                            name  year   price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014  450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014  370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006  158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010  225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007  130000     120000  Petrol  Individual
#
#   transmission         owner  mileage  engine  max_power  seats
# 0       Manual   First Owner    23.40  1248.0      74.00      5
# 1       Manual  Second Owner    21.14  1498.0     103.52      5
# 2       Manual   Third Owner    17.70  1497.0      78.00      5
# 3       Manual   First Owner    23.00  1396.0      90.00      5
# 4       Manual   First Owner    16.10  1298.0      88.20      5

# %% [markdown]
# - Loading the cleaned data from car_cleaned  .csv to confirm the save worked

# %% [markdown]
# ## Summary Statistics

# %%
df.columns
# Out:
# Index(['name', 'year', 'price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='str')

# %% [markdown]
# #### Average(Mean)

# %%
print("year    -",df['year'].mean())
# Out:
# year    - 2013.6091098541233

# %%
print("price    -",df['price'].mean())
# Out:
# price    - 526319.5507591545

# %%
print("seats    -",df['seats'].mean())
# Out:
# seats    - 5.4346531705864844

# %%
print("engine      -",df['engine'].mean())
# Out:
# engine      - 1430.8913367073533

# %%
print("mileage      -",df['mileage'].mean())
# Out:
# mileage      - 19.465309615957132

# %%
df.select_dtypes(include='number').mean()
# Out:
# year           2013.609110
# price        526319.550759
# km_driven     73402.297410
# mileage          19.465310
# engine         1430.891337
# max_power        87.765242
# seats             5.434653
# dtype: float64

# %% [markdown]
# ### Median

# %%
print("price    -",df['price'].median())
# Out:
# price    - 420000.0

# %%
print("year    -",df['year'].median())
# Out:
# year    - 2014.0

# %%
print("seats    -",df['seats'].median())
# Out:
# seats    - 5.0

# %%
print("engine      -",df['engine'].median())
# Out:
# engine      - 1248.0

# %%
print("mileage      -",df['mileage'].median())
# Out:
# mileage      - 19.44

# %%
df.select_dtypes(include='number').median()
# Out:
# year           2014.00
# price        420000.00
# km_driven     68221.50
# mileage          19.44
# engine         1248.00
# max_power        81.83
# seats             5.00
# dtype: float64

# %% [markdown]
# ### Mode

# %%
print("price    -",df['price'].mode())
# Out:
# price    - 0    300000
# Name: price, dtype: int64

# %%
print("year    -",df['year'].mode())
# Out:
# year    - 0    2017
# Name: year, dtype: int64

# %%
print("seats    -",df['seats'].mode())
# Out:
# seats    - 0    5
# Name: seats, dtype: int64

# %%
print("engine      -",df['engine'].mode())
# Out:
# engine      - 0    1248.0
# Name: engine, dtype: float64

# %%
print("mileage      -",df['mileage'].mode())
# Out:
# mileage      - 0    18.9
# Name: mileage, dtype: float64

# %%
df.select_dtypes(include='number').mode()
# Out:
#    year   price  km_driven  mileage  engine  max_power  seats
# 0  2017  300000     120000     18.9  1248.0       74.0      5

# %% [markdown]
# ### Standard Deviation

# %%
df.select_dtypes(include='number').std()
# Out:
# year              3.900648
# price        523539.802623
# km_driven     58699.802605
# mileage           4.049150
# engine          493.493277
# max_power        31.722272
# seats             0.984230
# dtype: float64

# %%
df.describe()
# Out:
#               year         price     km_driven     mileage       engine  \
# count  6718.000000  6.718000e+03  6.718000e+03  6718.00000  6718.000000
# mean   2013.609110  5.263196e+05  7.340230e+04    19.46531  1430.891337
# std       3.900648  5.235398e+05  5.869980e+04     4.04915   493.493277
# min    1994.000000  2.999900e+04  1.000000e+00     0.00000   624.000000
# 25%    2011.000000  2.500000e+05  3.800000e+04    16.80000  1197.000000
# 50%    2014.000000  4.200000e+05  6.822150e+04    19.44000  1248.000000
# 75%    2017.000000  6.500000e+05  1.000000e+05    22.50000  1498.000000
# max    2020.000000  1.000000e+07  2.360457e+06    42.00000  3604.000000
#
#          max_power        seats
# count  6718.000000  6718.000000
# mean     87.765242     5.434653
# std      31.722272     0.984230
# min      32.800000     2.000000
# 25%      67.100000     5.000000
# 50%      81.830000     5.000000
# 75%     100.000000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# - Cars are from 1983 to 2020 mostly recent years
# - Mileage,Engine and power are mostly in normal range
# - most vehicles are five seat and outlier is 14

# %% [markdown]
# ###  Inside  The Data

# %%
df.describe(include=str)
# Out:
#                           name    fuel seller_type transmission        owner
# count                     6718    6718        6718         6718         6718
# unique                    1983       4           3            2            5
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                       118    3658        6025         6143         4176

# %% [markdown]
# - Most vehicles are First owner cars
# - The majority of cars have manuel transmission
# - The most frequent  fuel type iss Diesel
# - The  most common seller type is individual
# - The most common car model  is Maruti Swift Dzire

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate Analysis
#
#    - Histograme,kde,box plot - numerical
#    - Countplot,pie chart - categorical

# %% [markdown]
# ### Bivariate Analysis
#
#    - Bar plot - category vs numerical
#    - line plot(time series) and scatter - categorical

# %% [markdown]
# ### Multivariate Analysis
#
#    - heat map - correlation
#    - pair plot - numerical

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Histogram

# %% [markdown]
# - Distribution of numerical data

# %%
df_new['mileage'].max()
# Out:
# np.float64(42.0)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="year",bins=10,color="red")
plt.title("Distribution of the year")
plt.show()

# %% [markdown]
# - Peak years : 2017 to 2018
# - Most cars are from 2010 - 2020
# - Very few  cars before 2005
# - Reason : The second hand market has more recent cars,old cars are rarely listed

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="price",bins=20,color="red")
plt.title(" price of the cars")
plt.show()

# %% [markdown]
# - Most people perfer affordable cars,so their number is high
# - Expensive cars are less common because fewer people can afford them

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="engine",bins=10,color="green")
plt.title("Distribution of the engine")
plt.show()

# %% [markdown]
# - Highest count 1200 to 1500
# - Reason : 1200 to 1500 cc gives good mileage + power low price ,so most people prefer it

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="mileage",bins=10,color="green")
plt.title("Mileage of the cars")
plt.show()

# %% [markdown]
# - Most car have mileage between 15 to 25 kmpl
# - peak is around 18 to 22 kmpl

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="max_power",bins=20,color="yellow")
plt.title("Max power of cars")
plt.show()

# %% [markdown]
# - peak range : 50 - 100 bhp ,Highest count - 3000 cars
# - Rare range : 200 bhp - very few cars
# - Reason : low midpower cars are affordable and fuel efficient ,so they dominate the market

# %% [markdown]
# ### kde plot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="mileage",bins=10,color="green",kde=True)
plt.title("Mileage of the cars")
plt.show()

# %% [markdown]
# - Most car :Give 18 to 22 km/l mileage
# - very few cars: Gives less than 10 km/l

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure size                                                                                                                                                                                                                                                                                                                      adjust
sns.histplot(data=df_new,x="max_power",bins=10,color="red",kde=True)
plt.title("Max power of cars")
plt.show()

# %% [markdown]
# - Peak range: most cars have maximum power between 60 to 100 bhp
# - low count : cars with >200 bhp are very rare
# - 60=100 bhp cars use less fuel and cost less money.so most people buy them ,cars with high power are costly ,so very few people buy them

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="year",bins=10,color="red",kde=True)
plt.title("Distribution of year")
plt.show()

# %% [markdown]
# - Most car made in 2012 to 2018
# - Very few cars made before year 2000
# - Reason : People sell new cars more,old cars are not used much

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.histplot(data=df_new,x="engine",bins=10,color="red",kde=True)
plt.title("Distribution of engine")
plt.show()

# %% [markdown]
# - common range : 1200 to 1500 cc most cars
# - Rare range : 3000 cc very few cars
# - reason : 1200 - 1500 cc engine give good mileage and enough power.They are also cheap so most people buy these cars .big engine are costly and use more
#   costly and use more fuel,so people buy less

# %% [markdown]
# ### Box plot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.boxplot(data=df_new,x="mileage",color="red")
plt.title("Mileage of the cars")
plt.show()

# %% [markdown]
# - The white line shows the middle value
# - A few cars have very low mileage near 0 and very hogh mileage 30-40
# - More outliers on the high mileage value
# - Majority of cars give 17-23 mileage .Extreme mileage car are rare in the data set

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.boxplot(data=df_new,x="year",color="green")
plt.title("Distribution of year")
plt.show()

# %% [markdown]
# - Most cars are recent models
#
# The majority of cars are between 2012–2018, showing a concentration of newer vehicles.
# - Left-skewed distribution
#
# Several older cars (before 2005) appear as outliers, pulling the distribution to the left.
# - The median year is around 2014–2015, indicating typical cars in the dataset are fairly modern.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) # figure sizr adjust
sns.boxplot(data=df_new,x="engine",color="yellow")
plt.title("engine of the cars")
plt.show()

# %% [markdown]
# - Most engines are around 1200–1500 cc, so typical cars are normal daily-use vehicles.
# - There are several cars with very high engine sizes (2000–3500 cc), but they are fewer and shown as outliers.
# - The data is skewed to the right, meaning a small number of cars have much bigger engines compared to most.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) 
sns.boxplot(data=df_new,x="max_power",color="red")
plt.title("Max power of cars")
plt.show()

# %% [markdown]
# - Box: The cars have power 70 - 100 bhp -most common cars
# - Middle line : Average power is 85 bhp
# - Outliers :many dots from 150 - 400 bhp on right power sports cars one dot near 0 bhp on left -maybe wrong data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4)) 
sns.boxplot(data=df_new,x="price",color="red")
plt.title("price of the car")
plt.show()

# %% [markdown]
# - Box :Half the cars cost 5 -10 lakhs -most common price range
# - Middle line : Average prices is 7 to 8 lakh
# - Outliers : lots of dots from 20 lakh to 1 crore on right -very costly laxury cars

# %% [markdown]
# ### count plot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='fuel',data=df_new )
plt.title("Count of fuel Types")
plt.show()

# %% [markdown]
# - The most common fuel typr is diesel
# - Used car market here strongly prefers diesel and petrol

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='transmission',data=df_new )
plt.title("Transmission count")
plt.show()

# %% [markdown]
# - Manual: 6300 cars are manual most common type
# - Automatic : only 700 cars are automatic very few
# - Ratio : For every 9 manual cars these only 1 automatic

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='owner',data=df_new )
plt.title("Owner Type Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - As owner number increases ,car count drop fast
# - Most used carss listed are being sold by the first owner
# - 60%+ cars are First owner ,so resale value may be higher for mostof the data set

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='seller_type',data=df_new )
plt.title("Seller Type Count")
plt.show()

# %% [markdown]
# - Individual sellers usually have differeent pricing vs dealers .This skew affects price modeling
# - Most cars are sold by individuals

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.countplot(x='fuel',hue='transmission',data=df_new )
plt.title("Fuel Type vs Transmission")
plt.show()

# %% [markdown]
# - Manuals are more affordable and widely preferred in price -sensitive markets

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x=df['transmission'],y=df['engine'])
# Out:
# <Axes: xlabel='transmission', ylabel='engine'>

# %% [markdown]
# - Automatic cars come with bigger engines. Manual cars use smaller engines to keep cost and mileage better
# - Engine size depends on transmission

# %%
sns.barplot(x=df['fuel'],y=df['price'])
# Out:
# <Axes: xlabel='fuel', ylabel='price'>

# %% [markdown]
# - Diesel cars have highest price
# - Fuel type stongly affects car price

# %%
sns.barplot(x=df['transmission'],y=df['price'])
# Out:
# <Axes: xlabel='transmission', ylabel='price'>

# %% [markdown]
# - Automatic cars are premium and cost 9 lakh more on average than budget manual cars

# %% [markdown]
# ### Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,5))
sns.scatterplot(x='mileage',y='price',data=df_new)
plt.title("price vs Manufacturing Year")
plt.xlabel("mileage")
plt.ylabel("price")
plt.show()

# %% [markdown]
# - Cheap cars usually give 10-30 kmpl mileage.Costly cars mostly have 10-20 kmpl .High price and high mileage together is very rare

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,6))
sns.scatterplot(x='km_driven',y='price',data=df_new)
plt.title("Price vs Kilometers Driven" )
plt.xlabel("kilometers driven")
plt.ylabel("price")
plt.show()

# %% [markdown]
# - When a car is driven more, its price usually goes down
#
#
# - Kilometers driven is very important to decide a car’s price
#
#
# - For better resale value, cars with low kilometers are best; expensive cars lose value faster if used more

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Heat map

# %%
plt.Figure(figsize=(2,1))
numeric_cols=df_new.select_dtypes(include=['float64','int64']).corr()
sns.heatmap(numeric_cols,annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - price increases with max power and engine
# - Bigger cars have bigger engines and more seats
# - Mileage decreases with engine size and seats
# - More km driven reduces price
# - Never cars have higher price

# %% [markdown]
# #### 1. How does the manufacturing year affect the price of  a car?

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,5))
sns.scatterplot(x='year',y='price',data=df_new)
plt.title("price vs Manufacturing Year")
plt.xlabel("Year")
plt.ylabel("price")
plt.show()

# %% [markdown]
# #### 2.Does automatic car have higher prices than manual cars ?

# %%
import matplotlib.pyplot as plt
cars=['manual','automatic']
prices=[8,10]
plt.bar(cars,prices)
plt.title("Manual vs Automatic car price comparison")
plt.xlabel("car type")
plt.ylabel("price")
plt.show()

# %% [markdown]
# #### 3. Does the seller type (individual vs dealer ) influence the selling price

# %%
import matplotlib.pyplot as plt
seller_type=['individual','dealer']
prices=[6.5,8.0]
plt.bar(seller_type,prices)
plt.title("Effect of seller type on car price")
plt.xlabel("seller type")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# The car dataset shows how different factors affect the selling price of cars. The most important factors are year, kilometers driven, engine power, and ownership. Newer cars usually have higher prices because they are in better condition and have more modern features. Cars with lower kilometers driven are also more valuable because they are less used.
#
# Engine capacity and maximum power also play a big role. Cars with higher power and bigger engines generally have higher prices. Fuel type also has some influence. Diesel cars often have slightly higher value because they give better mileage and are preferred for long-distance travel.
#
# Most of the cars in the dataset use manual transmission, and many are sold by individual owners instead of dealers. Cars with first ownership have better value compared to second or third owners, as they are considered more reliable.
#
# The torque column was removed from the dataset because it had inconsistent or complex values, making it difficult to analyze properly.
#
# Overall, the dataset clearly shows that car condition, performance, and usage history are the main factors that determine the price. Buyers usually prefer cars that are newer, less used, and more powerful.
